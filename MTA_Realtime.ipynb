# %%
#Connecting to MTA Realtime Data Feeds
#Using General Transit Feed Specification (GTFS) Realtime Protocol Buffers

import requests
import nyct_realtime_pb2

onetoseven_url = "https://api-endpoint.mta.info/Dataservice/mtagtfsfeeds/nyct%2Fgtfs"

ace = onetoseven_url + "-ace"
bdfm = onetoseven_url + "-bdfm"
g = onetoseven_url + "-g"
jz = onetoseven_url + "-jz"
nqrw = onetoseven_url + "-nqrw"
l = onetoseven_url + "-l"

#numerical url is not included in this array ....?
API_list = [ace, bdfm, g, jz, nqrw, l]

# %%
#API_list is not brought into this function yet it is called there. same with onetoseven_url.
def get_correct_url(name):
    if isinstance(name, str):
        name = name.lower()
    else:
        return onetoseven_url

    for api in API_list:
        if name in api:
            return api

def get_train_info(name):
    
    url = get_correct_url(name)
    response = requests.get(url)

    if response.status_code == 200:
        data = response.content
        print(f"Data for {name.upper()} train retrieved successfully.")
        # Further processing of data can be done here
        return data
    else:
        print(f"Failed to retrieve data for {name.upper()} train. Status code: {response.status_code}")


train_name = "a"
a_train_data = get_train_info(train_name)
#So far we have just retrieved the data from the MTA API for the ACE trains... All of them, with stops not specified and there are several of each train.
# Out:
# Data for A train retrieved successfully.

# %%
#Parsing GTFS Realtime Data
feed = gtfs_realtime_pb2.FeedMessage()
feed.ParseFromString(a_train_data)

print(feed.entity)
#for entity in feed.entity:
#    print(entity)
# Out:
# [id: "000001A"
# trip_update {
#   trip {
#     trip_id: "086350_A..S58R"
#     start_time: "14:23:00"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721434
#     }
#     departure {
#       time: 1769721434
#     }
#     stop_id: "H09S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721544
#     }
#     departure {
#       time: 1769721544
#     }
#     stop_id: "H10S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721634
#     }
#     departure {
#       time: 1769721634
#     }
#     stop_id: "H11S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000002A"
# vehicle {
#   trip {
#     trip_id: "086350_A..S58R"
#     start_time: "14:23:00"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   current_stop_sequence: 33
#   current_status: STOPPED_AT
#   timestamp: 1769721434
#   stop_id: "H09S"
# }
# , id: "000003A"
# trip_update {
#   trip {
#     trip_id: "087450_A..N55R"
#     start_time: "14:34:33"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721439
#     }
#     departure {
#       time: 1769721439
#     }
#     stop_id: "A05N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721507
#     }
#     departure {
#       time: 1769721507
#     }
#     stop_id: "A03N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721657
#     }
#     departure {
#       time: 1769721657
#     }
#     stop_id: "A02N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000004A"
# vehicle {
#   trip {
#     trip_id: "087450_A..N55R"
#     start_time: "14:34:33"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   current_stop_sequence: 34
#   current_status: STOPPED_AT
#   timestamp: 1769721439
#   stop_id: "A05N"
# }
# , id: "000005A"
# trip_update {
#   trip {
#     trip_id: "088950_A..N54R"
#     start_time: "14:49:30"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721439
#     }
#     departure {
#       time: 1769721439
#     }
#     stop_id: "A03N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721507
#     }
#     departure {
#       time: 1769721507
#     }
#     stop_id: "A02N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000006A"
# vehicle {
#   trip {
#     trip_id: "088950_A..N54R"
#     start_time: "14:49:30"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   current_stop_sequence: 28
#   current_status: STOPPED_AT
#   timestamp: 1769721439
#   stop_id: "A03N"
# }
# , id: "000007A"
# trip_update {
#   trip {
#     trip_id: "087800_A..S58R"
#     start_time: "14:38:00"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721534
#     }
#     departure {
#       time: 1769721534
#     }
#     stop_id: "H06S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721669
#     }
#     departure {
#       time: 1769721669
#     }
#     stop_id: "H07S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721819
#     }
#     departure {
#       time: 1769721819
#     }
#     stop_id: "H08S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721909
#     }
#     departure {
#       time: 1769721909
#     }
#     stop_id: "H09S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722029
#     }
#     departure {
#       time: 1769722029
#     }
#     stop_id: "H10S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722119
#     }
#     departure {
#       time: 1769722119
#     }
#     stop_id: "H11S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000008A"
# vehicle {
#   trip {
#     trip_id: "087800_A..S58R"
#     start_time: "14:38:00"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   current_stop_sequence: 29
#   current_status: STOPPED_AT
#   timestamp: 1769721319
#   stop_id: "H04S"
# }
# , id: "000009A"
# trip_update {
#   trip {
#     trip_id: "089000_A..N55R"
#     start_time: "14:50:00"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721439
#     }
#     departure {
#       time: 1769721439
#     }
#     stop_id: "A09N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721531
#     }
#     departure {
#       time: 1769721531
#     }
#     stop_id: "A07N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721591
#     }
#     departure {
#       time: 1769721591
#     }
#     stop_id: "A06N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721711
#     }
#     departure {
#       time: 1769721711
#     }
#     stop_id: "A05N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721891
#     }
#     departure {
#       time: 1769721891
#     }
#     stop_id: "A03N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722041
#     }
#     departure {
#       time: 1769722041
#     }
#     stop_id: "A02N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000010A"
# vehicle {
#   trip {
#     trip_id: "089000_A..N55R"
#     start_time: "14:50:00"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   current_stop_sequence: 31
#   current_status: STOPPED_AT
#   timestamp: 1769721439
#   stop_id: "A09N"
# }
# , id: "000011A"
# trip_update {
#   trip {
#     trip_id: "089300_A..S58R"
#     start_time: "14:53:00"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721509
#     }
#     departure {
#       time: 1769721509
#     }
#     stop_id: "H02S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721599
#     }
#     departure {
#       time: 1769721599
#     }
#     stop_id: "H03S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722019
#     }
#     departure {
#       time: 1769722019
#     }
#     stop_id: "H04S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722304
#     }
#     departure {
#       time: 1769722304
#     }
#     stop_id: "H06S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722424
#     }
#     departure {
#       time: 1769722424
#     }
#     stop_id: "H07S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722559
#     }
#     departure {
#       time: 1769722559
#     }
#     stop_id: "H08S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722649
#     }
#     departure {
#       time: 1769722649
#     }
#     stop_id: "H09S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722769
#     }
#     departure {
#       time: 1769722769
#     }
#     stop_id: "H10S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722859
#     }
#     departure {
#       time: 1769722859
#     }
#     stop_id: "H11S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000012A"
# vehicle {
#   trip {
#     trip_id: "089300_A..S58R"
#     start_time: "14:53:00"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   current_stop_sequence: 26
#   current_status: STOPPED_AT
#   timestamp: 1769721374
#   stop_id: "A61S"
# }
# , id: "000013A"
# trip_update {
#   trip {
#     trip_id: "089800_A..S57R"
#     start_time: "14:58:00"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721443
#     }
#     departure {
#       time: 1769721443
#     }
#     stop_id: "A61S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721534
#     }
#     departure {
#       time: 1769721534
#     }
#     stop_id: "A63S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721684
#     }
#     departure {
#       time: 1769721684
#     }
#     stop_id: "A64S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721774
#     }
#     departure {
#       time: 1769721774
#     }
#     stop_id: "A65S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000014A"
# vehicle {
#   trip {
#     trip_id: "089800_A..S57R"
#     start_time: "14:58:00"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   current_stop_sequence: 26
#   current_status: STOPPED_AT
#   timestamp: 1769721443
#   stop_id: "A61S"
# }
# , id: "000015A"
# trip_update {
#   trip {
#     trip_id: "090400_A..N54R"
#     start_time: "15:04:00"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721439
#     }
#     departure {
#       time: 1769721439
#     }
#     stop_id: "A07N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721507
#     }
#     departure {
#       time: 1769721507
#     }
#     stop_id: "A06N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721627
#     }
#     departure {
#       time: 1769721627
#     }
#     stop_id: "A05N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721807
#     }
#     departure {
#       time: 1769721807
#     }
#     stop_id: "A03N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721957
#     }
#     departure {
#       time: 1769721957
#     }
#     stop_id: "A02N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000016A"
# vehicle {
#   trip {
#     trip_id: "090400_A..N54R"
#     start_time: "15:04:00"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   current_stop_sequence: 25
#   current_status: STOPPED_AT
#   timestamp: 1769721439
#   stop_id: "A07N"
# }
# , id: "000017A"
# trip_update {
#   trip {
#     trip_id: "090500_A..N55R"
#     start_time: "15:05:14"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721439
#     }
#     departure {
#       time: 1769721439
#     }
#     stop_id: "A27N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721627
#     }
#     departure {
#       time: 1769721627
#     }
#     stop_id: "A24N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722077
#     }
#     departure {
#       time: 1769722077
#     }
#     stop_id: "A15N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722257
#     }
#     departure {
#       time: 1769722257
#     }
#     stop_id: "A12N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722467
#     }
#     departure {
#       time: 1769722467
#     }
#     stop_id: "A09N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722587
#     }
#     departure {
#       time: 1769722587
#     }
#     stop_id: "A07N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722647
#     }
#     departure {
#       time: 1769722647
#     }
#     stop_id: "A06N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722767
#     }
#     departure {
#       time: 1769722767
#     }
#     stop_id: "A05N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722947
#     }
#     departure {
#       time: 1769722947
#     }
#     stop_id: "A03N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723097
#     }
#     departure {
#       time: 1769723097
#     }
#     stop_id: "A02N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000018A"
# vehicle {
#   trip {
#     trip_id: "090500_A..N55R"
#     start_time: "15:05:14"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   current_stop_sequence: 27
#   current_status: STOPPED_AT
#   timestamp: 1769721439
#   stop_id: "A27N"
# }
# , id: "000019A"
# trip_update {
#   trip {
#     trip_id: "090650_A..S58R"
#     start_time: "15:06:30"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721442
#     }
#     departure {
#       time: 1769721442
#     }
#     stop_id: "A48S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721652
#     }
#     departure {
#       time: 1769721652
#     }
#     stop_id: "A51S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721952
#     }
#     departure {
#       time: 1769721952
#     }
#     stop_id: "A55S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722072
#     }
#     departure {
#       time: 1769722072
#     }
#     stop_id: "A57S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722162
#     }
#     departure {
#       time: 1769722162
#     }
#     stop_id: "A59S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722282
#     }
#     departure {
#       time: 1769722282
#     }
#     stop_id: "A60S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722372
#     }
#     departure {
#       time: 1769722372
#     }
#     stop_id: "A61S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722582
#     }
#     departure {
#       time: 1769722582
#     }
#     stop_id: "H02S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722672
#     }
#     departure {
#       time: 1769722672
#     }
#     stop_id: "H03S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723092
#     }
#     departure {
#       time: 1769723092
#     }
#     stop_id: "H04S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723377
#     }
#     departure {
#       time: 1769723377
#     }
#     stop_id: "H06S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723512
#     }
#     departure {
#       time: 1769723512
#     }
#     stop_id: "H07S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723662
#     }
#     departure {
#       time: 1769723662
#     }
#     stop_id: "H08S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723752
#     }
#     departure {
#       time: 1769723752
#     }
#     stop_id: "H09S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723872
#     }
#     departure {
#       time: 1769723872
#     }
#     stop_id: "H10S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723962
#     }
#     departure {
#       time: 1769723962
#     }
#     stop_id: "H11S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000020A"
# vehicle {
#   trip {
#     trip_id: "090650_A..S58R"
#     start_time: "15:06:30"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   current_stop_sequence: 20
#   current_status: STOPPED_AT
#   timestamp: 1769721442
#   stop_id: "A48S"
# }
# , id: "000021A"
# trip_update {
#   trip {
#     trip_id: "091400_A..S57R"
#     start_time: "15:14:00"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721536
#     }
#     departure {
#       time: 1769721536
#     }
#     stop_id: "A46S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721686
#     }
#     departure {
#       time: 1769721686
#     }
#     stop_id: "A48S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721896
#     }
#     departure {
#       time: 1769721896
#     }
#     stop_id: "A51S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722196
#     }
#     departure {
#       time: 1769722196
#     }
#     stop_id: "A55S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722316
#     }
#     departure {
#       time: 1769722316
#     }
#     stop_id: "A57S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722406
#     }
#     departure {
#       time: 1769722406
#     }
#     stop_id: "A59S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722526
#     }
#     departure {
#       time: 1769722526
#     }
#     stop_id: "A60S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722616
#     }
#     departure {
#       time: 1769722616
#     }
#     stop_id: "A61S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722736
#     }
#     departure {
#       time: 1769722736
#     }
#     stop_id: "A63S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722886
#     }
#     departure {
#       time: 1769722886
#     }
#     stop_id: "A64S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722976
#     }
#     departure {
#       time: 1769722976
#     }
#     stop_id: "A65S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000022A"
# vehicle {
#   trip {
#     trip_id: "091400_A..S57R"
#     start_time: "15:14:00"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   current_stop_sequence: 18
#   current_status: STOPPED_AT
#   timestamp: 1769721344
#   stop_id: "A42S"
# }
# , id: "000023A"
# trip_update {
#   trip {
#     trip_id: "092500_A..N55R"
#     start_time: "15:25:30"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721439
#     }
#     departure {
#       time: 1769721439
#     }
#     stop_id: "A42N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721507
#     }
#     departure {
#       time: 1769721507
#     }
#     stop_id: "A41N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721627
#     }
#     departure {
#       time: 1769721627
#     }
#     stop_id: "A40N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721807
#     }
#     departure {
#       time: 1769721807
#     }
#     stop_id: "A38N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721897
#     }
#     departure {
#       time: 1769721897
#     }
#     stop_id: "A36N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722017
#     }
#     departure {
#       time: 1769722017
#     }
#     stop_id: "A34N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722167
#     }
#     departure {
#       time: 1769722167
#     }
#     stop_id: "A32N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722317
#     }
#     departure {
#       time: 1769722317
#     }
#     stop_id: "A31N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722497
#     }
#     departure {
#       time: 1769722497
#     }
#     stop_id: "A28N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722587
#     }
#     departure {
#       time: 1769722587
#     }
#     stop_id: "A27N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722857
#     }
#     departure {
#       time: 1769722857
#     }
#     stop_id: "A24N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723307
#     }
#     departure {
#       time: 1769723307
#     }
#     stop_id: "A15N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723487
#     }
#     departure {
#       time: 1769723487
#     }
#     stop_id: "A12N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723697
#     }
#     departure {
#       time: 1769723697
#     }
#     stop_id: "A09N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723817
#     }
#     departure {
#       time: 1769723817
#     }
#     stop_id: "A07N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723877
#     }
#     departure {
#       time: 1769723877
#     }
#     stop_id: "A06N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723997
#     }
#     departure {
#       time: 1769723997
#     }
#     stop_id: "A05N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724177
#     }
#     departure {
#       time: 1769724177
#     }
#     stop_id: "A03N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724327
#     }
#     departure {
#       time: 1769724327
#     }
#     stop_id: "A02N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000024A"
# vehicle {
#   trip {
#     trip_id: "092500_A..N55R"
#     start_time: "15:25:30"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   current_stop_sequence: 18
#   current_status: STOPPED_AT
#   timestamp: 1769721439
#   stop_id: "A42N"
# }
# , id: "000025A"
# trip_update {
#   trip {
#     trip_id: "092000_A..N54R"
#     start_time: "15:20:00"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721434
#     }
#     departure {
#       time: 1769721434
#     }
#     stop_id: "A15N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721597
#     }
#     departure {
#       time: 1769721597
#     }
#     stop_id: "A12N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721807
#     }
#     departure {
#       time: 1769721807
#     }
#     stop_id: "A09N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721927
#     }
#     departure {
#       time: 1769721927
#     }
#     stop_id: "A07N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721987
#     }
#     departure {
#       time: 1769721987
#     }
#     stop_id: "A06N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722107
#     }
#     departure {
#       time: 1769722107
#     }
#     stop_id: "A05N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722287
#     }
#     departure {
#       time: 1769722287
#     }
#     stop_id: "A03N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722437
#     }
#     departure {
#       time: 1769722437
#     }
#     stop_id: "A02N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000026A"
# vehicle {
#   trip {
#     trip_id: "092000_A..N54R"
#     start_time: "15:20:00"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   current_stop_sequence: 22
#   current_status: STOPPED_AT
#   timestamp: 1769721434
#   stop_id: "A15N"
# }
# , id: "000027A"
# trip_update {
#   trip {
#     trip_id: "093000_A..S57R"
#     start_time: "15:30:30"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721439
#     }
#     departure {
#       time: 1769721439
#     }
#     stop_id: "A34S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721507
#     }
#     departure {
#       time: 1769721507
#     }
#     stop_id: "A36S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721627
#     }
#     departure {
#       time: 1769721627
#     }
#     stop_id: "A38S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721807
#     }
#     departure {
#       time: 1769721807
#     }
#     stop_id: "A40S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721957
#     }
#     departure {
#       time: 1769721957
#     }
#     stop_id: "A41S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722047
#     }
#     departure {
#       time: 1769722047
#     }
#     stop_id: "A42S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722317
#     }
#     departure {
#       time: 1769722317
#     }
#     stop_id: "A46S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722467
#     }
#     departure {
#       time: 1769722467
#     }
#     stop_id: "A48S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722677
#     }
#     departure {
#       time: 1769722677
#     }
#     stop_id: "A51S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722977
#     }
#     departure {
#       time: 1769722977
#     }
#     stop_id: "A55S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723097
#     }
#     departure {
#       time: 1769723097
#     }
#     stop_id: "A57S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723187
#     }
#     departure {
#       time: 1769723187
#     }
#     stop_id: "A59S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723307
#     }
#     departure {
#       time: 1769723307
#     }
#     stop_id: "A60S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723397
#     }
#     departure {
#       time: 1769723397
#     }
#     stop_id: "A61S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723517
#     }
#     departure {
#       time: 1769723517
#     }
#     stop_id: "A63S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723667
#     }
#     departure {
#       time: 1769723667
#     }
#     stop_id: "A64S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723757
#     }
#     departure {
#       time: 1769723757
#     }
#     stop_id: "A65S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000028A"
# vehicle {
#   trip {
#     trip_id: "093000_A..S57R"
#     start_time: "15:30:30"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   current_stop_sequence: 13
#   current_status: STOPPED_AT
#   timestamp: 1769721439
#   stop_id: "A34S"
# }
# , id: "000029A"
# trip_update {
#   trip {
#     trip_id: "092100_A..S58R"
#     start_time: "15:21:03"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721507
#     }
#     departure {
#       time: 1769721507
#     }
#     stop_id: "A41S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721597
#     }
#     departure {
#       time: 1769721597
#     }
#     stop_id: "A42S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721867
#     }
#     departure {
#       time: 1769721867
#     }
#     stop_id: "A46S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722017
#     }
#     departure {
#       time: 1769722017
#     }
#     stop_id: "A48S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722227
#     }
#     departure {
#       time: 1769722227
#     }
#     stop_id: "A51S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722527
#     }
#     departure {
#       time: 1769722527
#     }
#     stop_id: "A55S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722647
#     }
#     departure {
#       time: 1769722647
#     }
#     stop_id: "A57S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722737
#     }
#     departure {
#       time: 1769722737
#     }
#     stop_id: "A59S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722857
#     }
#     departure {
#       time: 1769722857
#     }
#     stop_id: "A60S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722947
#     }
#     departure {
#       time: 1769722947
#     }
#     stop_id: "A61S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723157
#     }
#     departure {
#       time: 1769723157
#     }
#     stop_id: "H02S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723247
#     }
#     departure {
#       time: 1769723247
#     }
#     stop_id: "H03S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723667
#     }
#     departure {
#       time: 1769723667
#     }
#     stop_id: "H04S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723952
#     }
#     departure {
#       time: 1769723952
#     }
#     stop_id: "H06S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724087
#     }
#     departure {
#       time: 1769724087
#     }
#     stop_id: "H07S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724237
#     }
#     departure {
#       time: 1769724237
#     }
#     stop_id: "H08S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724327
#     }
#     departure {
#       time: 1769724327
#     }
#     stop_id: "H09S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724447
#     }
#     departure {
#       time: 1769724447
#     }
#     stop_id: "H10S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724537
#     }
#     departure {
#       time: 1769724537
#     }
#     stop_id: "H11S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000030A"
# vehicle {
#   trip {
#     trip_id: "092100_A..S58R"
#     start_time: "15:21:03"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   current_stop_sequence: 16
#   current_status: STOPPED_AT
#   timestamp: 1769721389
#   stop_id: "A40S"
# }
# , id: "000031A"
# trip_update {
#   trip {
#     trip_id: "093950_A..N54R"
#     start_time: "15:39:30"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721439
#     }
#     departure {
#       time: 1769721439
#     }
#     stop_id: "A34N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721541
#     }
#     departure {
#       time: 1769721541
#     }
#     stop_id: "A32N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721691
#     }
#     departure {
#       time: 1769721691
#     }
#     stop_id: "A31N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721871
#     }
#     departure {
#       time: 1769721871
#     }
#     stop_id: "A28N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721961
#     }
#     departure {
#       time: 1769721961
#     }
#     stop_id: "A27N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722201
#     }
#     departure {
#       time: 1769722201
#     }
#     stop_id: "A24N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722651
#     }
#     departure {
#       time: 1769722651
#     }
#     stop_id: "A15N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722831
#     }
#     departure {
#       time: 1769722831
#     }
#     stop_id: "A12N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723041
#     }
#     departure {
#       time: 1769723041
#     }
#     stop_id: "A09N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723161
#     }
#     departure {
#       time: 1769723161
#     }
#     stop_id: "A07N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723221
#     }
#     departure {
#       time: 1769723221
#     }
#     stop_id: "A06N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723341
#     }
#     departure {
#       time: 1769723341
#     }
#     stop_id: "A05N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723521
#     }
#     departure {
#       time: 1769723521
#     }
#     stop_id: "A03N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723671
#     }
#     departure {
#       time: 1769723671
#     }
#     stop_id: "A02N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000032A"
# vehicle {
#   trip {
#     trip_id: "093950_A..N54R"
#     start_time: "15:39:30"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   current_stop_sequence: 16
#   current_status: STOPPED_AT
#   timestamp: 1769721439
#   stop_id: "A34N"
# }
# , id: "000033A"
# trip_update {
#   trip {
#     trip_id: "094800_A..N55R"
#     start_time: "15:48:32"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721534
#     }
#     departure {
#       time: 1769721534
#     }
#     stop_id: "H03N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721669
#     }
#     departure {
#       time: 1769721669
#     }
#     stop_id: "H02N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721729
#     }
#     departure {
#       time: 1769721729
#     }
#     stop_id: "H01N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721939
#     }
#     departure {
#       time: 1769721939
#     }
#     stop_id: "A61N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722029
#     }
#     departure {
#       time: 1769722029
#     }
#     stop_id: "A60N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722119
#     }
#     departure {
#       time: 1769722119
#     }
#     stop_id: "A59N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722209
#     }
#     departure {
#       time: 1769722209
#     }
#     stop_id: "A57N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722314
#     }
#     departure {
#       time: 1769722314
#     }
#     stop_id: "A55N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722599
#     }
#     departure {
#       time: 1769722599
#     }
#     stop_id: "A51N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722809
#     }
#     departure {
#       time: 1769722809
#     }
#     stop_id: "A48N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722959
#     }
#     departure {
#       time: 1769722959
#     }
#     stop_id: "A46N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723259
#     }
#     departure {
#       time: 1769723259
#     }
#     stop_id: "A42N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723379
#     }
#     departure {
#       time: 1769723379
#     }
#     stop_id: "A41N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723499
#     }
#     departure {
#       time: 1769723499
#     }
#     stop_id: "A40N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723679
#     }
#     departure {
#       time: 1769723679
#     }
#     stop_id: "A38N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723769
#     }
#     departure {
#       time: 1769723769
#     }
#     stop_id: "A36N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723889
#     }
#     departure {
#       time: 1769723889
#     }
#     stop_id: "A34N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724039
#     }
#     departure {
#       time: 1769724039
#     }
#     stop_id: "A32N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724189
#     }
#     departure {
#       time: 1769724189
#     }
#     stop_id: "A31N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724369
#     }
#     departure {
#       time: 1769724369
#     }
#     stop_id: "A28N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724459
#     }
#     departure {
#       time: 1769724459
#     }
#     stop_id: "A27N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724669
#     }
#     departure {
#       time: 1769724669
#     }
#     stop_id: "A24N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769725119
#     }
#     departure {
#       time: 1769725119
#     }
#     stop_id: "A15N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769725299
#     }
#     departure {
#       time: 1769725299
#     }
#     stop_id: "A12N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769725539
#     }
#     departure {
#       time: 1769725539
#     }
#     stop_id: "A09N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769725689
#     }
#     departure {
#       time: 1769725689
#     }
#     stop_id: "A07N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769725749
#     }
#     departure {
#       time: 1769725749
#     }
#     stop_id: "A06N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769725869
#     }
#     departure {
#       time: 1769725869
#     }
#     stop_id: "A05N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769726064
#     }
#     departure {
#       time: 1769726064
#     }
#     stop_id: "A03N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769726229
#     }
#     departure {
#       time: 1769726229
#     }
#     stop_id: "A02N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000034A"
# vehicle {
#   trip {
#     trip_id: "094800_A..N55R"
#     start_time: "15:48:32"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   current_stop_sequence: 6
#   current_status: STOPPED_AT
#   timestamp: 1769721174
#   stop_id: "H04N"
# }
# , id: "000035A"
# trip_update {
#   trip {
#     trip_id: "094900_A..S58R"
#     start_time: "15:49:30"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721507
#     }
#     departure {
#       time: 1769721507
#     }
#     stop_id: "A24S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721672
#     }
#     departure {
#       time: 1769721672
#     }
#     stop_id: "A27S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721747
#     }
#     departure {
#       time: 1769721747
#     }
#     stop_id: "A28S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721927
#     }
#     departure {
#       time: 1769721927
#     }
#     stop_id: "A31S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722047
#     }
#     departure {
#       time: 1769722047
#     }
#     stop_id: "A32S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722197
#     }
#     departure {
#       time: 1769722197
#     }
#     stop_id: "A34S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722317
#     }
#     departure {
#       time: 1769722317
#     }
#     stop_id: "A36S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722437
#     }
#     departure {
#       time: 1769722437
#     }
#     stop_id: "A38S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722617
#     }
#     departure {
#       time: 1769722617
#     }
#     stop_id: "A40S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722767
#     }
#     departure {
#       time: 1769722767
#     }
#     stop_id: "A41S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722857
#     }
#     departure {
#       time: 1769722857
#     }
#     stop_id: "A42S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723127
#     }
#     departure {
#       time: 1769723127
#     }
#     stop_id: "A46S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723277
#     }
#     departure {
#       time: 1769723277
#     }
#     stop_id: "A48S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723487
#     }
#     departure {
#       time: 1769723487
#     }
#     stop_id: "A51S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723787
#     }
#     departure {
#       time: 1769723787
#     }
#     stop_id: "A55S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723907
#     }
#     departure {
#       time: 1769723907
#     }
#     stop_id: "A57S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723997
#     }
#     departure {
#       time: 1769723997
#     }
#     stop_id: "A59S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724117
#     }
#     departure {
#       time: 1769724117
#     }
#     stop_id: "A60S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724207
#     }
#     departure {
#       time: 1769724207
#     }
#     stop_id: "A61S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724417
#     }
#     departure {
#       time: 1769724417
#     }
#     stop_id: "H02S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724507
#     }
#     departure {
#       time: 1769724507
#     }
#     stop_id: "H03S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724927
#     }
#     departure {
#       time: 1769724927
#     }
#     stop_id: "H04S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769725212
#     }
#     departure {
#       time: 1769725212
#     }
#     stop_id: "H06S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769725347
#     }
#     departure {
#       time: 1769725347
#     }
#     stop_id: "H07S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769725497
#     }
#     departure {
#       time: 1769725497
#     }
#     stop_id: "H08S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769725587
#     }
#     departure {
#       time: 1769725587
#     }
#     stop_id: "H09S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769725707
#     }
#     departure {
#       time: 1769725707
#     }
#     stop_id: "H10S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769725797
#     }
#     departure {
#       time: 1769725797
#     }
#     stop_id: "H11S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000036A"
# vehicle {
#   trip {
#     trip_id: "094900_A..S58R"
#     start_time: "15:49:30"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   current_stop_sequence: 7
#   current_status: STOPPED_AT
#   timestamp: 1769721068
#   stop_id: "A15S"
# }
# , id: "000037A"
# trip_update {
#   trip {
#     trip_id: "095950_A..N54R"
#     start_time: "15:59:30"
#     start_date: "20260129"
#     route_id: "A"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721439
#     }
#     departure {
#       time: 1769721439
#     }
#     stop_id: "A51N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721559
#     }
#     departure {
#       time: 1769721559
#     }
#     stop_id: "A48N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721709
#     }
#     departure {
#       time: 1769721709
#     }
#     stop_id: "A46N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722009
#     }
#     departure {
#       time: 1769722009
#     }
#     stop_id: "A42N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722129
#     }
#     departure {
#       time: 1769722129
#     }
#     stop_id: "A41N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722249
#     }
#     departure {
#       time: 1769722249
#     }
#     stop_id: "A40N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722429
#     }
#     departure {
#       time: 1769722429
#     }
#     stop_id: "A38N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722519
#     }
#     departure {
#       time: 1769722519
#     }
#     stop_id: "A36N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722639
#     }
#     departure {
#       time: 1769722639
#     }
#     stop_id: "A34N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722789
#     }
#     departure {
#       time: 1769722789
#     }
#     stop_id: "A32N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722939
#     }
#     departure {
#       time: 1769722939
#     }
#     stop_id: "A31N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723119
#     }
#     departure {
#       time: 1769723119
#     }
#     stop_id: "A28N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723209
#     }
#     departure {
#       time: 1769723209
#     }
#     stop_id: "A27N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
# ...
#     route_id: "H"
#   }
# }
# , id: "000018H"
# vehicle {
#   trip {
#     trip_id: "091750_H..N21R"
#     start_time: "15:17:13"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   current_stop_sequence: 5
#   current_status: STOPPED_AT
#   timestamp: 1769718468
#   stop_id: "H19N"
# }
# , id: "000019H"
# trip_update {
#   trip {
#     trip_id: "092900_H..N21R"
#     start_time: "15:29:30"
#     start_date: "20260129"
#     route_id: "H"
#   }
# }
# , id: "000020H"
# vehicle {
#   trip {
#     trip_id: "092900_H..N21R"
#     start_time: "15:29:30"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   current_stop_sequence: 5
#   current_status: STOPPED_AT
#   timestamp: 1769719208
#   stop_id: "H19N"
# }
# , id: "000021H"
# trip_update {
#   trip {
#     trip_id: "094450_H..N21R"
#     start_time: "15:44:48"
#     start_date: "20260129"
#     route_id: "H"
#   }
# }
# , id: "000022H"
# vehicle {
#   trip {
#     trip_id: "094450_H..N21R"
#     start_time: "15:44:48"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   current_stop_sequence: 5
#   current_status: STOPPED_AT
#   timestamp: 1769720096
#   stop_id: "H19N"
# }
# , id: "000023H"
# trip_update {
#   trip {
#     trip_id: "095750_H..N21R"
#     start_time: "15:58:30"
#     start_date: "20260129"
#     route_id: "H"
#   }
# }
# , id: "000024H"
# vehicle {
#   trip {
#     trip_id: "095750_H..N21R"
#     start_time: "15:58:30"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   current_stop_sequence: 5
#   current_status: STOPPED_AT
#   timestamp: 1769721359
#   stop_id: "H19N"
# }
# , id: "000025H"
# trip_update {
#   trip {
#     trip_id: "096500_H..S21R"
#     start_time: "16:05:00"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721439
#     }
#     departure {
#       time: 1769721439
#     }
#     stop_id: "H13S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721439
#     }
#     departure {
#       time: 1769721439
#     }
#     stop_id: "H14S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721509
#     }
#     departure {
#       time: 1769721509
#     }
#     stop_id: "H15S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000026H"
# vehicle {
#   trip {
#     trip_id: "096500_H..S21R"
#     start_time: "16:05:00"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   current_stop_sequence: 4
#   current_status: STOPPED_AT
#   timestamp: 1769721439
#   stop_id: "H14S"
# }
# , id: "000027H"
# trip_update {
#   trip {
#     trip_id: "097050_H..N21R"
#     start_time: "16:11:00"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721539
#     }
#     departure {
#       time: 1769721539
#     }
#     stop_id: "H04N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721821
#     }
#     departure {
#       time: 1769721821
#     }
#     stop_id: "H19N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000028H"
# vehicle {
#   trip {
#     trip_id: "097050_H..N21R"
#     start_time: "16:11:00"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   current_stop_sequence: 3
#   current_status: STOPPED_AT
#   timestamp: 1769721371
#   stop_id: "H12N"
# }
# , id: "000029H"
# trip_update {
#   trip {
#     trip_id: "097800_H..S21R"
#     start_time: "16:18:00"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721480
#     }
#     departure {
#       time: 1769721480
#     }
#     stop_id: "H19S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721570
#     }
#     departure {
#       time: 1769721570
#     }
#     stop_id: "H04S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721840
#     }
#     departure {
#       time: 1769721840
#     }
#     stop_id: "H12S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721960
#     }
#     departure {
#       time: 1769721960
#     }
#     stop_id: "H13S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722020
#     }
#     departure {
#       time: 1769722020
#     }
#     stop_id: "H14S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722110
#     }
#     departure {
#       time: 1769722110
#     }
#     stop_id: "H15S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000030H"
# vehicle {
#   trip {
#     trip_id: "097800_H..S21R"
#     start_time: "16:18:00"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   timestamp: 1769721480
#   stop_id: "H19S"
# }
# , id: "000031H"
# trip_update {
#   trip {
#     trip_id: "098400_H..N21R"
#     start_time: "16:24:00"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721840
#     }
#     departure {
#       time: 1769721840
#     }
#     stop_id: "H15N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769721960
#     }
#     departure {
#       time: 1769721960
#     }
#     stop_id: "H14N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722080
#     }
#     departure {
#       time: 1769722080
#     }
#     stop_id: "H13N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722170
#     }
#     departure {
#       time: 1769722170
#     }
#     stop_id: "H12N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722455
#     }
#     departure {
#       time: 1769722455
#     }
#     stop_id: "H04N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722620
#     }
#     departure {
#       time: 1769722620
#     }
#     stop_id: "H19N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000032H"
# vehicle {
#   trip {
#     trip_id: "098400_H..N21R"
#     start_time: "16:24:00"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   timestamp: 1769721840
#   stop_id: "H15N"
# }
# , id: "000033H"
# trip_update {
#   trip {
#     trip_id: "099150_H..S21R"
#     start_time: "16:31:30"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722290
#     }
#     departure {
#       time: 1769722290
#     }
#     stop_id: "H19S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722380
#     }
#     departure {
#       time: 1769722380
#     }
#     stop_id: "H04S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722650
#     }
#     departure {
#       time: 1769722650
#     }
#     stop_id: "H12S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722770
#     }
#     departure {
#       time: 1769722770
#     }
#     stop_id: "H13S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722830
#     }
#     departure {
#       time: 1769722830
#     }
#     stop_id: "H14S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722920
#     }
#     departure {
#       time: 1769722920
#     }
#     stop_id: "H15S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000034H"
# vehicle {
#   trip {
#     trip_id: "099150_H..S21R"
#     start_time: "16:31:30"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   timestamp: 1769722290
#   stop_id: "H19S"
# }
# , id: "000035H"
# trip_update {
#   trip {
#     trip_id: "099800_H..N21R"
#     start_time: "16:38:00"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722680
#     }
#     departure {
#       time: 1769722680
#     }
#     stop_id: "H15N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722800
#     }
#     departure {
#       time: 1769722800
#     }
#     stop_id: "H14N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769722920
#     }
#     departure {
#       time: 1769722920
#     }
#     stop_id: "H13N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723010
#     }
#     departure {
#       time: 1769723010
#     }
#     stop_id: "H12N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723295
#     }
#     departure {
#       time: 1769723295
#     }
#     stop_id: "H04N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723460
#     }
#     departure {
#       time: 1769723460
#     }
#     stop_id: "H19N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000036H"
# vehicle {
#   trip {
#     trip_id: "099800_H..N21R"
#     start_time: "16:38:00"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   timestamp: 1769722680
#   stop_id: "H15N"
# }
# , id: "000037H"
# trip_update {
#   trip {
#     trip_id: "100500_H..S21R"
#     start_time: "16:45:00"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723100
#     }
#     departure {
#       time: 1769723100
#     }
#     stop_id: "H19S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723190
#     }
#     departure {
#       time: 1769723190
#     }
#     stop_id: "H04S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723460
#     }
#     departure {
#       time: 1769723460
#     }
#     stop_id: "H12S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723580
#     }
#     departure {
#       time: 1769723580
#     }
#     stop_id: "H13S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723640
#     }
#     departure {
#       time: 1769723640
#     }
#     stop_id: "H14S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723730
#     }
#     departure {
#       time: 1769723730
#     }
#     stop_id: "H15S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000038H"
# vehicle {
#   trip {
#     trip_id: "100500_H..S21R"
#     start_time: "16:45:00"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   timestamp: 1769723100
#   stop_id: "H19S"
# }
# , id: "000039H"
# trip_update {
#   trip {
#     trip_id: "101150_H..N21R"
#     start_time: "16:51:30"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723490
#     }
#     departure {
#       time: 1769723490
#     }
#     stop_id: "H15N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723610
#     }
#     departure {
#       time: 1769723610
#     }
#     stop_id: "H14N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723730
#     }
#     departure {
#       time: 1769723730
#     }
#     stop_id: "H13N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769723820
#     }
#     departure {
#       time: 1769723820
#     }
#     stop_id: "H12N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724105
#     }
#     departure {
#       time: 1769724105
#     }
#     stop_id: "H04N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724270
#     }
#     departure {
#       time: 1769724270
#     }
#     stop_id: "H19N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000040H"
# vehicle {
#   trip {
#     trip_id: "101150_H..N21R"
#     start_time: "16:51:30"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   timestamp: 1769723490
#   stop_id: "H15N"
# }
# , id: "000041H"
# trip_update {
#   trip {
#     trip_id: "102200_H..S21R"
#     start_time: "17:02:00"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724120
#     }
#     departure {
#       time: 1769724120
#     }
#     stop_id: "H19S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724210
#     }
#     departure {
#       time: 1769724210
#     }
#     stop_id: "H04S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724480
#     }
#     departure {
#       time: 1769724480
#     }
#     stop_id: "H12S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724600
#     }
#     departure {
#       time: 1769724600
#     }
#     stop_id: "H13S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724660
#     }
#     departure {
#       time: 1769724660
#     }
#     stop_id: "H14S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724750
#     }
#     departure {
#       time: 1769724750
#     }
#     stop_id: "H15S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000042H"
# vehicle {
#   trip {
#     trip_id: "102200_H..S21R"
#     start_time: "17:02:00"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   timestamp: 1769724120
#   stop_id: "H19S"
# }
# , id: "000043H"
# trip_update {
#   trip {
#     trip_id: "102750_H..N21R"
#     start_time: "17:07:30"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724450
#     }
#     departure {
#       time: 1769724450
#     }
#     stop_id: "H15N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724570
#     }
#     departure {
#       time: 1769724570
#     }
#     stop_id: "H14N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724690
#     }
#     departure {
#       time: 1769724690
#     }
#     stop_id: "H13N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769724780
#     }
#     departure {
#       time: 1769724780
#     }
#     stop_id: "H12N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769725065
#     }
#     departure {
#       time: 1769725065
#     }
#     stop_id: "H04N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769725230
#     }
#     departure {
#       time: 1769725230
#     }
#     stop_id: "H19N"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000044H"
# vehicle {
#   trip {
#     trip_id: "102750_H..N21R"
#     start_time: "17:07:30"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   timestamp: 1769724450
#   stop_id: "H15N"
# }
# , id: "000045H"
# trip_update {
#   trip {
#     trip_id: "103700_H..S21R"
#     start_time: "17:17:00"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   stop_time_update {
#     arrival {
#       time: 1769725020
#     }
#     departure {
#       time: 1769725020
#     }
#     stop_id: "H19S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769725110
#     }
#     departure {
#       time: 1769725110
#     }
#     stop_id: "H04S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769725380
#     }
#     departure {
#       time: 1769725380
#     }
#     stop_id: "H12S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769725500
#     }
#     departure {
#       time: 1769725500
#     }
#     stop_id: "H13S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769725560
#     }
#     departure {
#       time: 1769725560
#     }
#     stop_id: "H14S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
#   stop_time_update {
#     arrival {
#       time: 1769725650
#     }
#     departure {
#       time: 1769725650
#     }
#     stop_id: "H15S"
#     departure_occupancy_status: NO_DATA_AVAILABLE
#   }
# }
# , id: "000046H"
# vehicle {
#   trip {
#     trip_id: "103700_H..S21R"
#     start_time: "17:17:00"
#     start_date: "20260129"
#     route_id: "H"
#   }
#   timestamp: 1769725020
#   stop_id: "H19S"
# }
# ]
